# %%
using PyPlot
using Revise
using AIDA
# Out:
# ┌ Warning: no Manifest.toml file found, static paths used
# └ @ Revise C:\Users\s151781\.julia\packages\Revise\1boD5\src\packagedef.jl:1369
# ┌ Info: Precompiling AIDA [02ab3c64-7f6e-4624-92b1-4056b28faae1]
# └ @ Base loading.jl:1278

# %%
z = zeros(100,100)
for kx = 1:100
    for ky = 1:100
        z[kx, ky] = generate_user_response([kx/100, ky/100])
    end
end

# %%
plt.imshow(z)
plt.colorbar()
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x000000004063CCA0>
