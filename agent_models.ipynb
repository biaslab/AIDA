# %% [markdown]
# # Agent

# %% [markdown]
# Ask Bert
# \begin{align}
# p(r_t,u_t,\omega_t,a_t | \omega_{t-1}) \propto \underbrace{p(r_t|u_t) p(u_t|\omega_t)}_{\text{likelihood}} \underbrace{p(\omega_t | \omega_{t-1}, a_t)}_{\text{state transition}}\underbrace{p(a_t)}_{\text{control}} \qquad (1)
# \end{align}

# %% [markdown]
# \begin{align}
# p(r_t,u_t,\omega_t | \omega_{t-1}) \propto p(r_t|\omega_t)p(\omega_t | \omega_{t-1}, u_t)p(u_t) \qquad (2)
# \end{align}

# %% [markdown]
# \begin{align}
# p(r_t,u_t,\omega_t \mid u_{t-1}) \propto \underbrace{p(r_t \mid u_t)}_{\text{response}} \underbrace{ p(u_t \mid u_{t-1}) p(u_t \mid \omega_t)}_{\text{perception }p(u_t \mid u_{t-1},\omega_t)} \underbrace{p(\omega_t)}_{\substack{\text{control} \\ \text{prior}}}  \qquad (3)
# \end{align}

# %%
using ForneyLab
using ProgressMeter
using LinearAlgebra
using Plots
# Out:
# ┌ Info: Precompiling ForneyLab [9fc3f58a-c2cc-5bff-9419-6a294fefdca9]
# └ @ Base loading.jl:1278

# %%
# Model (1)
n_samples = 1
fg = FactorGraph()

# State prior
@RV ω_0 ~ GaussianMeanPrecision(placeholder(:m_ω_0), placeholder(:w_ω_0))


# Transition and observation model
ω = Vector{Variable}(undef, n_samples)
a = Vector{Variable}(undef, n_samples)
u = Vector{Variable}(undef, n_samples)
p = Vector{Variable}(undef, n_samples)
r = Vector{Variable}(undef, n_samples)

ω_i_min = ω_0
for i in 1:n_samples

    @RV a[i] ~ Gamma(3.0, 2.0)
    @RV ω[i] ~ GaussianMeanPrecision(ω_i_min, a[i])
    @RV u[i] ~ GaussianMeanPrecision(ω[i], 100.0)
    
    f(z) = 1/(1+ exp(-z))
    @RV p[i] ~ Nonlinear{Sampling}(u[i], g=f)
    @RV r[i] ~ Bernoulli(p[i])

    # Data placeholder
    placeholder(r[i], :r, index=i)

    # Reset state for next step
    ω_i_min = ω[i]
end
q = PosteriorFactorization([ω_0; ω], p, a, ids=[:Ω :P :A])
algo = messagePassingAlgorithm(free_energy=true)
source_code = algorithmSourceCode(algo, free_energy=true)
println(source_code)
# Out:
# begin
#
# function stepP!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 4))
#
# messages[1] = ruleVBGaussianMeanPrecisionOut(nothing, marginals[:ω_1], ProbabilityDistribution(Univariate, PointMass, m=100.0))
# messages[2] = ruleVBBernoulliIn1(ProbabilityDistribution(Univariate, PointMass, m=data[:r][1]), nothing)
# messages[3] = ruleSPNonlinearSIn1MN(f, messages[2], nothing)
# messages[4] = ruleSPNonlinearSOutNM(f, nothing, messages[1])
#
# marginals[:p_1] = messages[4].dist * messages[2].dist
# marginals[:u_1] = messages[1].dist * messages[3].dist
#
# return marginals
#
# end
#
# function stepA!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 2))
#
# messages[1] = ruleVBGammaOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=3.0), ProbabilityDistribution(Univariate, PointMass, m=2.0))
# messages[2] = ruleSVBGaussianMeanPrecisionW(marginals[:ω_1_ω_0], nothing)
#
# marginals[:a_1] = messages[1].dist * messages[2].dist
#
# return marginals
#
# end
#
# function stepΩ!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 4))
#
# messages[1] = ruleVBGaussianMeanPrecisionOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=data[:m_ω_0]), ProbabilityDistribution(Univariate, PointMass, m=data[:w_ω_0]))
# messages[2] = ruleSVBGaussianMeanPrecisionOutVGD(nothing, messages[1], marginals[:a_1])
# messages[3] = ruleVBGaussianMeanPrecisionM(marginals[:u_1], nothing, ProbabilityDistribution(Univariate, PointMass, m=100.0))
# messages[4] = ruleSVBGaussianMeanPrecisionMGVD(messages[3], nothing, marginals[:a_1])
#
# marginals[:ω_0] = messages[1].dist * messages[4].dist
# marginals[:ω_1] = messages[2].dist * messages[3].dist
# marginals[:ω_1_ω_0] = ruleMGaussianMeanPrecisionGGD(messages[3], messages[1], marginals[:a_1])
#
# return marginals
#
# end
#
# function freeEnergy(data::Dict, marginals::Dict)
#
# F = 0.0
#
# F += averageEnergy(Bernoulli, ProbabilityDistribution(Univariate, PointMass, m=data[:r][1]), marginals[:p_1])
# F += averageEnergy(Gamma, marginals[:a_1], ProbabilityDistribution(Univariate, PointMass, m=3.0), ProbabilityDistribution(Univariate, PointMass, m=2.0))
# F += averageEnergy(GaussianMeanPrecision, marginals[:ω_0], ProbabilityDistribution(Univariate, PointMass, m=data[:m_ω_0]), ProbabilityDistribution(Univariate, PointMass, m=data[:w_ω_0]))
# F += averageEnergy(GaussianMeanPrecision, marginals[:ω_1_ω_0], marginals[:a_1])
# F += averageEnergy(GaussianMeanPrecision, marginals[:u_1], marginals[:ω_1], ProbabilityDistribution(Univariate, PointMass, m=100.0))
#
# F -= differentialEntropy(marginals[:a_1])
# F -= differentialEntropy(marginals[:u_1])
# F -= differentialEntropy(marginals[:ω_1_ω_0])
#
# return F
#
# end
#
# end # block

# %%
# Model (2)
n_samples = 1
fg = FactorGraph()

# State prior
@RV ω_0 ~ GaussianMeanPrecision(placeholder(:m_ω_0), placeholder(:w_ω_0))

# Transition and observation model
ω = Vector{Variable}(undef, n_samples)
u = Vector{Variable}(undef, n_samples)
p = Vector{Variable}(undef, n_samples)
r = Vector{Variable}(undef, n_samples)

ω_i_min = ω_0
for i in 1:n_samples

    @RV u[i] ~ Gamma(3, 2)
    
    f(x) = 1/(1+ exp(-x))

    @RV ω[i] ~ GaussianMeanPrecision(ω_i_min, u[i])

    @RV p[i] ~ Nonlinear{Sampling}(ω[i], g=f)
    
    @RV r[i] ~ Bernoulli(p[i])

    # Data placeholder
    placeholder(r[i], :r, index=i)

    # Reset state for next step
    ω_i_min = ω[i]
end
draw()
q = PosteriorFactorization(ω_0, ω, u, ids=[:Ω0 :Ω :U])
algo = messagePassingAlgorithm(free_energy=true)
source_code = algorithmSourceCode(algo, free_energy=true)
println(source_code)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="650pt" height="629pt"
#  viewBox="0.00 0.00 649.50 629.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 625)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-625 645.5,-625 645.5,4 -4,4"/>
# <!-- 16587192101252115087 -->
# <g id="node1" class="node">
# <title>16587192101252115087</title>
# <polygon fill="none" stroke="#000000" points="383.5,-522 311.5,-522 311.5,-450 383.5,-450 383.5,-522"/>
# <text text-anchor="middle" x="347.5" y="-488.8" font-family="Times,serif" font-size="9.00" fill="#000000">Ber</text>
# <text text-anchor="middle" x="347.5" y="-478.8" font-family="Times,serif" font-size="9.00" fill="#000000">bernoulli_1</text>
# </g>
# <!-- 5876271152233874960 -->
# <g id="node10" class="node">
# <title>5876271152233874960</title>
# <polygon fill="none" stroke="#000000" points="383.5,-405 311.5,-405 311.5,-333 383.5,-333 383.5,-405"/>
# <text text-anchor="middle" x="347.5" y="-371.8" font-family="Times,serif" font-size="9.00" fill="#000000">g{Sampling}</text>
# <text text-anchor="middle" x="347.5" y="-361.8" font-family="Times,serif" font-size="9.00" fill="#000000">nonlinear_1</text>
# </g>
# <!-- 16587192101252115087&#45;&#45;5876271152233874960 -->
# <g id="edge8" class="edge">
# <title>16587192101252115087&#45;&#45;5876271152233874960</title>
# <path fill="none" stroke="#000000" d="M347.5,-449.9415C347.5,-435.7071 347.5,-419.3833 347.5,-405.1409"/>
# <text text-anchor="start" x="347.5" y="-425.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">p_1</text>
# <text text-anchor="start" x="328.5" y="-407.7409" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="334.5" y="-443.5415" font-family="Times,serif" font-size="8.00" fill="#000000">2 p </text>
# </g>
# <!-- 11425093883619272855 -->
# <g id="node2" class="node">
# <title>11425093883619272855</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="472.5,-54 418.5,-54 418.5,0 472.5,0 472.5,-54"/>
# <text text-anchor="middle" x="445.5" y="-24.8" font-family="Times,serif" font-size="9.00" fill="#000000">clamp_2</text>
# </g>
# <!-- 14591177124531299800 -->
# <g id="node3" class="node">
# <title>14591177124531299800</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="89,-54 0,-54 0,0 89,0 89,-54"/>
# <text text-anchor="middle" x="44.5" y="-24.8" font-family="Times,serif" font-size="9.00" fill="#000000">placeholder_w_ω_0</text>
# </g>
# <!-- 14710939358468355748 -->
# <g id="node4" class="node">
# <title>14710939358468355748</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="641.5,-54 587.5,-54 587.5,0 641.5,0 641.5,-54"/>
# <text text-anchor="middle" x="614.5" y="-24.8" font-family="Times,serif" font-size="9.00" fill="#000000">clamp_1</text>
# </g>
# <!-- 2113255313219599529 -->
# <g id="node5" class="node">
# <title>2113255313219599529</title>
# <polygon fill="none" stroke="#000000" points="402,-288 293,-288 293,-216 402,-216 402,-288"/>
# <text text-anchor="middle" x="347.5" y="-254.8" font-family="Times,serif" font-size="9.00" fill="#000000">𝒩</text>
# <text text-anchor="middle" x="347.5" y="-244.8" font-family="Times,serif" font-size="9.00" fill="#000000">gaussianmeanprecision_2</text>
# </g>
# <!-- 7889984492936887506 -->
# <g id="node6" class="node">
# <title>7889984492936887506</title>
# <polygon fill="none" stroke="#000000" points="299,-171 190,-171 190,-99 299,-99 299,-171"/>
# <text text-anchor="middle" x="244.5" y="-137.8" font-family="Times,serif" font-size="9.00" fill="#000000">𝒩</text>
# <text text-anchor="middle" x="244.5" y="-127.8" font-family="Times,serif" font-size="9.00" fill="#000000">gaussianmeanprecision_1</text>
# </g>
# <!-- 2113255313219599529&#45;&#45;7889984492936887506 -->
# <g id="edge7" class="edge">
# <title>2113255313219599529&#45;&#45;7889984492936887506</title>
# <path fill="none" stroke="#000000" d="M315.7562,-215.9415C303.225,-201.7071 288.8545,-185.3833 276.3163,-171.1409"/>
# <text text-anchor="start" x="299.5" y="-191.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">ω_0</text>
# <text text-anchor="start" x="257.3163" y="-173.7409" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="300.7562" y="-209.5415" font-family="Times,serif" font-size="8.00" fill="#000000">2 m </text>
# </g>
# <!-- 15207325591409483884 -->
# <g id="node8" class="node">
# <title>15207325591409483884</title>
# <polygon fill="none" stroke="#000000" points="486.5,-171 414.5,-171 414.5,-99 486.5,-99 486.5,-171"/>
# <text text-anchor="middle" x="450.5" y="-137.8" font-family="Times,serif" font-size="9.00" fill="#000000">Gam</text>
# <text text-anchor="middle" x="450.5" y="-127.8" font-family="Times,serif" font-size="9.00" fill="#000000">gamma_1</text>
# </g>
# <!-- 2113255313219599529&#45;&#45;15207325591409483884 -->
# <g id="edge4" class="edge">
# <title>2113255313219599529&#45;&#45;15207325591409483884</title>
# <path fill="none" stroke="#000000" d="M379.2438,-215.9415C391.775,-201.7071 406.1455,-185.3833 418.6837,-171.1409"/>
# <text text-anchor="start" x="402.5" y="-191.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">u_1</text>
# <text text-anchor="start" x="399.6837" y="-173.7409" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="365.2438" y="-209.5415" font-family="Times,serif" font-size="8.00" fill="#000000">3 w </text>
# </g>
# <!-- 7889984492936887506&#45;&#45;14591177124531299800 -->
# <g id="edge5" class="edge">
# <title>7889984492936887506&#45;&#45;14591177124531299800</title>
# <path fill="none" stroke="#000000" d="M189.8491,-105.4885C158.2748,-88.4384 119.048,-67.2559 89.3061,-51.1953"/>
# <text text-anchor="start" x="144.5" y="-74.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">w_ω_0</text>
# <text text-anchor="start" x="89.3061" y="-53.7953" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="175.8491" y="-108.0885" font-family="Times,serif" font-size="8.00" fill="#000000">3 w </text>
# </g>
# <!-- 13214343795728477800 -->
# <g id="node9" class="node">
# <title>13214343795728477800</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="294.5,-54 204.5,-54 204.5,0 294.5,0 294.5,-54"/>
# <text text-anchor="middle" x="249.5" y="-24.8" font-family="Times,serif" font-size="9.00" fill="#000000">placeholder_m_ω_0</text>
# </g>
# <!-- 7889984492936887506&#45;&#45;13214343795728477800 -->
# <g id="edge2" class="edge">
# <title>7889984492936887506&#45;&#45;13214343795728477800</title>
# <path fill="none" stroke="#000000" d="M246.1788,-98.7371C246.854,-84.1526 247.6192,-67.6262 248.2447,-54.1146"/>
# <text text-anchor="start" x="247.5" y="-74.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">m_ω_0</text>
# <text text-anchor="start" x="229.2447" y="-56.7146" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="231.1788" y="-92.3371" font-family="Times,serif" font-size="8.00" fill="#000000">2 m </text>
# </g>
# <!-- 506197319725776280 -->
# <g id="node7" class="node">
# <title>506197319725776280</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="385,-621 310,-621 310,-567 385,-567 385,-621"/>
# <text text-anchor="middle" x="347.5" y="-591.8" font-family="Times,serif" font-size="9.00" fill="#000000">placeholder_r_1</text>
# </g>
# <!-- 506197319725776280&#45;&#45;16587192101252115087 -->
# <g id="edge6" class="edge">
# <title>506197319725776280&#45;&#45;16587192101252115087</title>
# <path fill="none" stroke="#000000" d="M347.5,-566.747C347.5,-553.2495 347.5,-536.7693 347.5,-522.2253"/>
# <text text-anchor="start" x="347.5" y="-542.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">r_1</text>
# <text text-anchor="start" x="328.5" y="-524.8253" font-family="Times,serif
# begin
#
# function stepU!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 2))
#
# messages[1] = ruleVBGammaOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=3), ProbabilityDistribution(Univariate, PointMass, m=2))
# messages[2] = ruleVBGaussianMeanPrecisionW(marginals[:ω_1], marginals[:ω_0], nothing)
#
# marginals[:u_1] = messages[1].dist * messages[2].dist
#
# return marginals
#
# end
#
# function stepΩ!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 4))
#
# messages[1] = ruleVBGaussianMeanPrecisionOut(nothing, marginals[:ω_0], marginals[:u_1])
# messages[2] = ruleVBBernoulliIn1(ProbabilityDistribution(Univariate, PointMass, m=data[:r][1]), nothing)
# messages[3] = ruleSPNonlinearSIn1MN(f, messages[2], nothing)
# messages[4] = ruleSPNonlinearSOutNM(f, nothing, messages[1])
#
# marginals[:p_1] = messages[4].dist * messages[2].dist
# marginals[:ω_1] = messages[1].dist * messages[3].dist
#
# return marginals
#
# end
#
# function stepΩ0!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 2))
#
# messages[1] = ruleVBGaussianMeanPrecisionOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=data[:m_ω_0]), ProbabilityDistribution(Univariate, PointMass, m=data[:w_ω_0]))
# messages[2] = ruleVBGaussianMeanPrecisionM(marginals[:ω_1], nothing, marginals[:u_1])
#
# marginals[:ω_0] = messages[1].dist * messages[2].dist
#
# return marginals
#
# end
#
# function freeEnergy(data::Dict, marginals::Dict)
#
# F = 0.0
#
# F += averageEnergy(Bernoulli, ProbabilityDistribution(Univariate, PointMass, m=data[:r][1]), marginals[:p_1])
# F += averageEnergy(Gamma, marginals[:u_1], ProbabilityDistribution(Univariate, PointMass, m=3), ProbabilityDistribution(Univariate, PointMass, m=2))
# F += averageEnergy(GaussianMeanPrecision, marginals[:ω_0], ProbabilityDistribution(Univariate, PointMass, m=data[:m_ω_0]), ProbabilityDistribution(Univariate, PointMass, m=data[:w_ω_0]))
# F += averageEnergy(GaussianMeanPrecision, marginals[:ω_1], marginals[:ω_0], marginals[:u_1])
#
# F -= differentialEntropy(marginals[:u_1])
# F -= differentialEntropy(marginals[:ω_0])
# F -= differentialEntropy(marginals[:ω_1])
#
# return F
#
# end
#
# end # block

# %%
# Model (3) fails due to multiple inputs of different distributions
n_samples = 1
fg = FactorGraph()

# State prior

@RV u_0 ~ GaussianMeanPrecision(placeholder(:m_u_0), placeholder(:w_u_0))

# Transition and observation model
ω = Vector{Variable}(undef, n_samples)
p = Vector{Variable}(undef, n_samples)
u = Vector{Variable}(undef, n_samples)
r = Vector{Variable}(undef, n_samples)

u_i_min = u_0
for i in 1:n_samples

    @RV ω[i] ~ Beta(1.0, 1.0)
    
    @RV u[i] ~ GaussianMeanPrecision(u_i_min, 100.0)
    
    sigmoid(x, z) = 1/(1+ exp(-(x+z)))
    @RV p[i] ~ Nonlinear{Sampling}(u[i], ω[i], g=sigmoid)
    @RV r[i] ~ Bernoulli(p[i])

    # Data placeholder
    placeholder(r[i], :r, index=i)

    # Reset state for next step
    u_i_min = u[i]
end
draw()
q = PosteriorFactorization(ω, u, ids=[:Ω :U])
algo = messagePassingAlgorithm(free_energy=true)
source_code = algorithmSourceCode(algo, free_energy=true)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="734pt" height="629pt"
#  viewBox="0.00 0.00 734.00 629.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 625)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-625 730,-625 730,4 -4,4"/>
# <!-- 14148136209743170974 -->
# <g id="node1" class="node">
# <title>14148136209743170974</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="54,-162 0,-162 0,-108 54,-108 54,-162"/>
# <text text-anchor="middle" x="27" y="-132.8" font-family="Times,serif" font-size="9.00" fill="#000000">clamp_2</text>
# </g>
# <!-- 9635957328786935328 -->
# <g id="node2" class="node">
# <title>9635957328786935328</title>
# <polygon fill="none" stroke="#000000" points="222,-288 150,-288 150,-216 222,-216 222,-288"/>
# <text text-anchor="middle" x="186" y="-254.8" font-family="Times,serif" font-size="9.00" fill="#000000">Beta</text>
# <text text-anchor="middle" x="186" y="-244.8" font-family="Times,serif" font-size="9.00" fill="#000000">beta_1</text>
# </g>
# <!-- 9635957328786935328&#45;&#45;14148136209743170974 -->
# <g id="edge9" class="edge">
# <title>9635957328786935328&#45;&#45;14148136209743170974</title>
# <path fill="none" stroke="#000000" d="M149.9204,-225.4509C120.7839,-204.0108 80.4229,-174.3112 54.02,-154.8827"/>
# <text text-anchor="start" x="112" y="-191.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">clamp_2</text>
# <text text-anchor="start" x="54.02" y="-157.4827" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="136.9204" y="-228.0509" font-family="Times,serif" font-size="8.00" fill="#000000">3 b </text>
# </g>
# <!-- 6914634977457005216 -->
# <g id="node7" class="node">
# <title>6914634977457005216</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="223,-162 169,-162 169,-108 223,-108 223,-162"/>
# <text text-anchor="middle" x="196" y="-132.8" font-family="Times,serif" font-size="9.00" fill="#000000">clamp_1</text>
# </g>
# <!-- 9635957328786935328&#45;&#45;6914634977457005216 -->
# <g id="edge10" class="edge">
# <title>9635957328786935328&#45;&#45;6914634977457005216</title>
# <path fill="none" stroke="#000000" d="M189.0819,-215.9415C190.5625,-198.6185 192.3076,-178.201 193.6747,-162.2064"/>
# <text text-anchor="start" x="192" y="-191.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">clamp_1</text>
# <text text-anchor="start" x="174.6747" y="-164.8064" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="177.0819" y="-209.5415" font-family="Times,serif" font-size="8.00" fill="#000000">2 a </text>
# </g>
# <!-- 9247697078806554825 -->
# <g id="node3" class="node">
# <title>9247697078806554825</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="410,-162 356,-162 356,-108 410,-108 410,-162"/>
# <text text-anchor="middle" x="383" y="-132.8" font-family="Times,serif" font-size="9.00" fill="#000000">clamp_3</text>
# </g>
# <!-- 1168489843262766985 -->
# <g id="node4" class="node">
# <title>1168489843262766985</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="522.5,-54 435.5,-54 435.5,0 522.5,0 522.5,-54"/>
# <text text-anchor="middle" x="479" y="-24.8" font-family="Times,serif" font-size="9.00" fill="#000000">placeholder_w_u_0</text>
# </g>
# <!-- 4165278879402515816 -->
# <g id="node5" class="node">
# <title>4165278879402515816</title>
# <polygon fill="none" stroke="#000000" points="634.5,-171 525.5,-171 525.5,-99 634.5,-99 634.5,-171"/>
# <text text-anchor="middle" x="580" y="-137.8" font-family="Times,serif" font-size="9.00" fill="#000000">𝒩</text>
# <text text-anchor="middle" x="580" y="-127.8" font-family="Times,serif" font-size="9.00" fill="#000000">gaussianmeanprecision_1</text>
# </g>
# <!-- 4165278879402515816&#45;&#45;1168489843262766985 -->
# <g id="edge5" class="edge">
# <title>4165278879402515816&#45;&#45;1168489843262766985</title>
# <path fill="none" stroke="#000000" d="M534.9904,-98.8545C528.7093,-93.1241 522.5227,-87.0765 517,-81 509.5211,-72.7712 502.2542,-63.0255 496.1123,-54.0938"/>
# <text text-anchor="start" x="517" y="-74.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">w_u_0</text>
# <text text-anchor="start" x="477.1123" y="-56.6938" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="520.9904" y="-92.4545" font-family="Times,serif" font-size="8.00" fill="#000000">3 w </text>
# </g>
# <!-- 14995289286316231626 -->
# <g id="node6" class="node">
# <title>14995289286316231626</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="726,-54 638,-54 638,0 726,0 726,-54"/>
# <text text-anchor="middle" x="682" y="-24.8" font-family="Times,serif" font-size="9.00" fill="#000000">placeholder_m_u_0</text>
# </g>
# <!-- 4165278879402515816&#45;&#45;14995289286316231626 -->
# <g id="edge7" class="edge">
# <title>4165278879402515816&#45;&#45;14995289286316231626</title>
# <path fill="none" stroke="#000000" d="M614.2483,-98.7371C628.0226,-84.1526 643.6308,-67.6262 656.3917,-54.1146"/>
# <text text-anchor="start" x="638" y="-74.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">m_u_0</text>
# <text text-anchor="start" x="637.3917" y="-56.7146" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="599.2483" y="-92.3371" font-family="Times,serif" font-size="8.00" fill="#000000">2 m </text>
# </g>
# <!-- 16096405115069515812 -->
# <g id="node8" class="node">
# <title>16096405115069515812</title>
# <polygon fill="none" stroke="#000000" points="325,-405 253,-405 253,-333 325,-333 325,-405"/>
# <text text-anchor="middle" x="289" y="-371.8" font-family="Times,serif" font-size="9.00" fill="#000000">g{Sampling}</text>
# <text text-anchor="middle" x="289" y="-361.8" font-family="Times,serif" font-size="9.00" fill="#000000">nonlinear_1</text>
# </g>
# <!-- 16096405115069515812&#45;&#45;9635957328786935328 -->
# <g id="edge6" class="edge">
# <title>16096405115069515812&#45;&#45;9635957328786935328</title>
# <path fill="none" stroke="#000000" d="M257.2562,-332.9415C244.725,-318.7071 230.3545,-302.3833 217.8163,-288.1409"/>
# <text text-anchor="start" x="241" y="-308.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">ω_1</text>
# <text text-anchor="start" x="198.8163" y="-290.7409" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="238.2562" y="-326.5415" font-family="Times,serif" font-size="8.00" fill="#000000">3 in2 </text>
# </g>
# <!-- 8421455896784479204 -->
# <g id="node11" class="node">
# <title>8421455896784479204</title>
# <polygon fill="none" stroke="#000000" points="446.5,-288 337.5,-288 337.5,-216 446.5,-216 446.5,-288"/>
# <text text-anchor="middle" x="392" y="-254.8" font-family="Times,serif" font-size="9.00" fill="#000000">𝒩</text>
# <text text-anchor="middle" x="392" y="-244.8" font-family="Times,serif" font-size="9.00" fill="#000000">gaussianmeanprecision_2</text>
# </g>
# <!-- 16096405115069515812&#45;&#45;8421455896784479204 -->
# <g id="edge1" class="edge">
# <title>16096405115069515812&#45;&#45;8421455896784479204</title>
# <path fill="none" stroke="#000000" d="M320.7438,-332.9415C333.275,-318.7071 347.6455,-302.3833 360.1837,-288.1409"/>
# <text text-anchor="start" x="344" y="-308.6" font-family="Times,serif" font-size="8.00" fill="#ff0000">u_1</text>
# <text text-anchor="start" x="341.1837" y="-290.7409" font-family="Times,serif" font-size="8.00" fill="#000000">1 out </text>
# <text text-anchor="start" x="301.7438" y="-326.5415" font-family="Times,serif" font-size="8.00" fill="#000000">2 in1 </text>
# </g>
# <!-- 6140178622539777057 -->
# <g id="node9" class="node">
# <title>6140178622539777057</title>
# <polygon fill="#d3d3d3" stroke="#000000" points="326.5,-621 251.5,-621 251.5,-567 326.5,-567 326.5,-621"/>
# <text text-anchor="middle" x="289"
# No applicable SumProductRule{Nonlinear{Sampling}} update for Nonlinear{Sampling} node with inbound types: Message{Beta,var_type} where var_type<:ForneyLab.VariateType, Message{GaussianMeanPrecision,var_type} where var_type<:ForneyLab.VariateType, Nothing
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] inferUpdateRule!(::ScheduleEntry, ::Type{SumProductRule{Nonlinear{Sampling}}}, ::Dict{Interface,Type}) at /Users/albertpod/.julia/dev/ForneyLab/src/algorithms/sum_product.jl:75
#  [3] inferUpdateRules!(::Array{ScheduleEntry,1}; inferred_outbound_types::Dict{Interface,Type}) at /Users/albertpod/.julia/dev/ForneyLab/src/message_passing.jl:194
#  [4] messagePassingSchedule(::PosteriorFactor) at /Users/albertpod/.julia/dev/ForneyLab/src/algorithms/posterior_factor.jl:76
#  [5] messagePassingAlgorithm(::Array{Variable,1}, ::PosteriorFactorization; id::Symbol, free_energy::Bool) at /Users/albertpod/.julia/dev/ForneyLab/src/algorithms/inference_algorithm.jl:68
#  [6] top-level scope at In[152]:34
#  [7] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [8] execute_code(::String, ::String) at /Users/albertpod/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/albertpod/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [10] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [11] invokelatest at ./essentials.jl:709 [inlined]
#  [12] eventloop(::ZMQ.Socket) at /Users/albertpod/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [13] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
# Model (3) hack around previous error
n_samples = 1
fg = FactorGraph()

# State prior
@RV u_0 ~ GaussianMeanPrecision(placeholder(:m_u_0), placeholder(:w_u_0))

# Transition and observation model
ω = Vector{Variable}(undef, n_samples)
ωsample = Vector{Variable}(undef, n_samples)
ωn = Vector{Variable}(undef, n_samples)
p = Vector{Variable}(undef, n_samples)
u = Vector{Variable}(undef, n_samples)
un = Vector{Variable}(undef, n_samples)
utr = Vector{Variable}(undef, n_samples)
r = Vector{Variable}(undef, n_samples)

u_i_min = u_0
for i in 1:n_samples

    @RV ω[i] ~ Beta(1.0, 1.0)
    βN(x) = x
    @RV ωsample[i] ~ Nonlinear{Sampling}(ω[i], g=βN)
    @RV ωn[i] ~ GaussianMeanPrecision(ωsample[i], 100.0)

    @RV utr[i] ~ GaussianMeanPrecision(u_i_min, 10.0)
    sumβN(x, y) = x + y
    @RV u[i] ~ Nonlinear{Sampling}(ωn[i], utr[i], g=sumβN)
    @RV un[i] ~ GaussianMeanPrecision(u[i], 100.0)
    sigmoid(x) = 1/(1+ exp(-(x)))
    @RV p[i] ~ Nonlinear{Sampling}(un[i], g=sigmoid)
    @RV r[i] ~ GaussianMeanPrecision(p[i], 1.0)

    # Data placeholder
    placeholder(r[i], :r, index=i)

    # Reset state for next step
    u_i_min = un[i]
end
q = PosteriorFactorization(ω, ωn, [u_0; un], ids=[:Ω :ΩN :U])
algo = messagePassingAlgorithm(free_energy=true)
source_code = algorithmSourceCode(algo, free_energy=true)
println(source_code)
# Out:
# begin
#
# function stepU!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 6))
#
# messages[1] = ruleVBGaussianMeanPrecisionOut(nothing, marginals[:u_1], ProbabilityDistribution(Univariate, PointMass, m=100.0))
# messages[2] = ruleVBGaussianMeanPrecisionM(ProbabilityDistribution(Univariate, PointMass, m=data[:r][1]), nothing, ProbabilityDistribution(Univariate, PointMass, m=1.0))
# messages[3] = ruleSPNonlinearSIn1MN(sigmoid, messages[2], nothing)
# messages[4] = ruleVBGaussianMeanPrecisionOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=data[:m_u_0]), ProbabilityDistribution(Univariate, PointMass, m=data[:w_u_0]))
# messages[5] = ruleVBGaussianMeanPrecisionM(marginals[:utr_1], nothing, ProbabilityDistribution(Univariate, PointMass, m=10.0))
# messages[6] = ruleSPNonlinearSOutNM(sigmoid, nothing, messages[1])
#
# marginals[:p_1] = messages[6].dist * messages[2].dist
# marginals[:u_0] = messages[4].dist * messages[5].dist
# marginals[:un_1] = messages[1].dist * messages[3].dist
#
# return marginals
#
# end
#
# function stepΩ!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 4))
#
# messages[1] = ruleVBBetaOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=1.0), ProbabilityDistribution(Univariate, PointMass, m=1.0))
# messages[2] = ruleSPNonlinearSOutNM(βN, nothing, messages[1])
# messages[3] = ruleVBGaussianMeanPrecisionM(marginals[:ωn_1], nothing, ProbabilityDistribution(Univariate, PointMass, m=100.0))
# messages[4] = ruleSPNonlinearSIn1MN(βN, messages[3], nothing)
#
# marginals[:ω_1] = messages[1].dist * messages[4].dist
# marginals[:ωsample_1] = messages[2].dist * messages[3].dist
#
# return marginals
#
# end
#
# function initΩN()
#
# messages = Array{Message}(undef, 6)
#
# messages[1] = Message(vague(GaussianMeanPrecision))
# messages[2] = Message(vague(GaussianMeanPrecision))
#
# return messages
#
# end
#
# function stepΩN!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 6))
#
# messages[1] = ruleVBGaussianMeanPrecisionOut(nothing, marginals[:u_0], ProbabilityDistribution(Univariate, PointMass, m=10.0))
# messages[2] = ruleVBGaussianMeanPrecisionOut(nothing, marginals[:ωsample_1], ProbabilityDistribution(Univariate, PointMass, m=100.0))
# messages[3] = ruleVBGaussianMeanPrecisionM(marginals[:un_1], nothing, ProbabilityDistribution(Univariate, PointMass, m=100.0))
# messages[4] = ruleSPNonlinearSInGX(sumβN, 1, messages[3], messages[2], messages[1])
# messages[5] = ruleSPNonlinearSInGX(sumβN, 2, messages[3], messages[2], messages[1])
# messages[6] = ruleSPNonlinearSOutNGX(sumβN, nothing, messages[2], messages[1])
#
# marginals[:u_1] = messages[6].dist * messages[3].dist
# marginals[:utr_1] = messages[1].dist * messages[5].dist
# marginals[:ωn_1] = messages[2].dist * messages[4].dist
# marginals[:ωn_1_utr_1] = ruleMNonlinearSInGX(sumβN, messages[3], messages[2], messages[1])
#
# return marginals
#
# end
#
# function freeEnergy(data::Dict, marginals::Dict)
#
# F = 0.0
#
# F += averageEnergy(Beta, marginals[:ω_1], ProbabilityDistribution(Univariate, PointMass, m=1.0), ProbabilityDistribution(Univariate, PointMass, m=1.0))
# F += averageEnergy(GaussianMeanPrecision, marginals[:u_0], ProbabilityDistribution(Univariate, PointMass, m=data[:m_u_0]), ProbabilityDistribution(Univariate, PointMass, m=data[:w_u_0]))
# F += averageEnergy(GaussianMeanPrecision, marginals[:ωn_1], marginals[:ωsample_1], ProbabilityDistribution(Univariate, PointMass, m=100.0))
# F += averageEnergy(GaussianMeanPrecision, marginals[:utr_1], marginals[:u_0], ProbabilityDistribution(Univariate, PointMass, m=10.0))
# F += averageEnergy(GaussianMeanPrecision, marginals[:un_1], marginals[:u_1], ProbabilityDistribution(Univariate, PointMass, m=100.0))
# F += averageEnergy(GaussianMeanPrecision, ProbabilityDistribution(Univariate, PointMass, m=data[:r][1]), marginals[:p_1], ProbabilityDistribution(Univariate, PointMass, m=1.0))
#
# F -= differentialEntropy(marginals[:u_0])
# F -= differentialEntropy(marginals[:un_1])
# F -= differentialEntropy(marginals[:ω_1])
# F -= differentialEntropy(marginals[:ωn_1_utr_1])
#
# return F
#
# end
#
# end # block
